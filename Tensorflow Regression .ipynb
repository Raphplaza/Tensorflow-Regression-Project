# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
#checking missing values
#df.isnull()
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(10,6))
sns.displot(df['price'])

# %%
sns.countplot(df['bedrooms'])
# Out:
# /Users/Raph/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
#Explore highly correlated features with label

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data = df,
                x = 'sqft_living',
                y = 'price',
               )
# Out:
# <AxesSubplot:xlabel='sqft_living', ylabel='price'>

# %%
sns.boxplot(x='bedrooms', 
            y='price',
            data = df)
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(
            y='lat', 
            x='price',
            data = df)
# Out:
# <AxesSubplot:xlabel='price', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(
            x='long', 
            y='price',
            data = df)
# Out:
# <AxesSubplot:xlabel='long', ylabel='price'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(
            x='long', 
            y='lat',
            data = df)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(
            x='long', 
            y='lat',
            hue = 'price',
            data = df)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
#dropping outliers to make dependencies visible

# %%
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
len(df['price']) * 0.01
# Out:
# 215.97

# %%
df_skip_top_1 = df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(
            data = df_skip_top_1,
            x='long', 
            y='lat',
            hue = 'price',
            palette='RdYlGn',
            edgecolor = None,
            alpha=0.2)
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
sns.boxplot(
        x = 'waterfront',
        y = 'price',
        data=df)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
#dropping unused features

# %%
df.drop('id',axis=1,inplace=True)

# %%
#converting date

# %%
type(df['date'][0])
# Out:
# str

# %%
from datetime import datetime

# %%
df['date'][0].split('/')[0]
# Out:
# '10'

# %%
df.head()
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
# 2   2/25/2015  180000.0         2       1.00          770     10000     1.0
# 3   12/9/2014  604000.0         4       3.00         1960      5000     1.0
# 4   2/18/2015  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
# ...

# %%
#Method 1
df['Day'] = df['date'].apply(lambda date:date.split('/')[0])
df['Month'] = df['date'].apply(lambda date:date.split('/')[1])
df['Year'] = df['date'].apply(lambda date:date.split('/')[2])

# %%
df.head(2)
# Out:
#          date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  10/13/2014  221900.0         3       1.00         1180      5650     1.0
# 1   12/9/2014  538000.0         3       2.25         2570      7242     2.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0           0     0          3  ...      1955             0    98178  47.5112
# 1           0     0          3  ...      1951          1991    98125  47.7210
#
#       long  sqft_living15  sqft_lot15  Day  Month  Year
# 0 -122.257           1340        5650   10     13  2014
# 1 -122.319           1690        7639   12      9  2014
#
# [2 rows x 23 columns]

# %%
#Method 2
df['date'] = pd.to_datetime(df['date'])

# %%
df['Month'] = df['date'].apply(lambda date:date.month)
df['Year'] = df['date'].apply(lambda date:date.year)

# %%
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  yr_built  yr_renovated  zipcode      lat  \
# 0           0     0          3  ...      1955             0    98178  47.5112
# 1           0     0          3  ...      1951          1991    98125  47.7210
# 2           0     0          3  ...      1933             0    98028  47.7379
# 3           0     0          5  ...      1965             0    98136  47.5208
# 4           0     0          3  ...      1987             0    98074  47.6168
#
# ...

# %%
df.drop('Day',axis=1,inplace=True)

# %%
sns.boxplot(x = 'Month',
            y = 'price',
            data = df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='price'>

# %%
df.groupby('Month').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df.groupby('Year').mean()['price'].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df.drop('date',axis=1,inplace=True)

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  ...  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7  ...              0      1955             0
# 1     0          3      7  ...            400      1951          1991
# 2     0          3      6  ...              0      1933             0
# 3     0          5      7  ...            910      1965             0
# 4     0          3      8  ...              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15  Month  Year
# ...

# %%
#zipcode is not a continous feature
#98178 is not greater than 98125

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
#70 different zipcodes is too much 
#to take the feature into acount.
#in our case we will drop the feature

df.drop('zipcode',axis=1,inplace=True)

# %%
df['yr_renovated'].value_counts()
# Out:
# 0       20683
# 2014       91
# 2013       37
# 2003       36
# 2007       35
#         ...
# 1948        1
# 1954        1
# 1951        1
# 1944        1
# 1959        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
# '0' is not a year
# but in this case we can leave the column,
# as the later the renovtion was the better

# %%
### Part3

# %%
X = df.drop('price',axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.30, random_state=101)

# %%
#Scaling post split to prevent data leakage

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (15117, 19)

# %%
# 19 incoming features - it's a good practice to 
# set 19 neurons

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(19, activation = 'relu'))
model.add(Dense(19, activation = 'relu'))
model.add(Dense(19, activation = 'relu'))
model.add(Dense(19, activation = 'relu'))

#Output neuron
model.add(Dense(1))

model.compile(optimizer='adam',
              loss = 'mse')

# %%
model.fit(X_train,y_train,
          validation_data=(X_test,y_test),
          batch_size = 128,
          epochs = 400)
# Out:
# Epoch 1/400
# 119/119 [==============================] - 2s 7ms/step - loss: 430242627584.0000 - val_loss: 418932359168.0000
# Epoch 2/400
# 119/119 [==============================] - 0s 4ms/step - loss: 429474873344.0000 - val_loss: 416283983872.0000
# Epoch 3/400
# 119/119 [==============================] - 1s 7ms/step - loss: 419034660864.0000 - val_loss: 392533377024.0000
# Epoch 4/400
# 119/119 [==============================] - 0s 4ms/step - loss: 366203863040.0000 - val_loss: 302952251392.0000
# Epoch 5/400
# 119/119 [==============================] - 0s 4ms/step - loss: 238015856640.0000 - val_loss: 155708801024.0000
# Epoch 6/400
# 119/119 [==============================] - 0s 4ms/step - loss: 122088587264.0000 - val_loss: 97357529088.0000
# Epoch 7/400
# 119/119 [==============================] - 0s 4ms/step - loss: 98791104512.0000 - val_loss: 94453915648.0000
# Epoch 8/400
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %%
### Evaluation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 101913.2657359182

# %%
mean_squared_error(y_test,predictions)**0.5
# Out:
# 164826.8501499744

# %%
df['price'].mean()
# Out:
# 540296.5735055795

# %%
#not too bad, not too good

# %%
explained_variance_score(y_test,
                         predictions)
# Out:
# 0.7951952306833394

# %%
## How to improve?

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test,
            predictions)
plt.plot(y_test,y_test,'r')

# %%
## Idea 1: drop top 1% percent of most expensive houses

# %%
#Using model to predict single value
df.drop('price',axis=1).iloc[0]
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# Month              10.0000
# Year             2014.0000
# Name: 0, dtype: float64

# %%
single_house = df.drop('price',axis=1).iloc[0]

# %%
single_house.values
# Out:
# array([ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#         1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#         7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#         0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#         5.65000e+03,  1.00000e+01,  2.01400e+03])

# %%
single_house.values.shape
# Out:
# (19,)

# %%
#Transforming 1D to 2D

# %%
single_house.values.reshape(-1,19)
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#          0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#          5.65000e+03,  1.00000e+01,  2.01400e+03]])

# %%
single_house.values.reshape(-1,19).shape
# Out:
# (1, 19)

# %%
single_house = scaler.transform(single_house.values.reshape(-1,19))

# %%
model.predict(single_house)
# Out:
# array([[282978.12]], dtype=float32)

# %%
df['price'][0]
# Out:
# 221900.0
